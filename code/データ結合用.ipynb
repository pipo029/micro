# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gdf_osyu_100m_mesh = gpd.read_file('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/奥州市　重心/gdf_osyu_100m_mesh.shp')

# %%
gdf_railway = pd.read_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/奥州市 最近傍鉄道/奥州市_最近傍線路.csv', encoding='shift-jis')

# %%
gdf_railway_test = pd.merge(gdf_osyu_100m_mesh, gdf_railway, on='Meshcode')

# %%
gdf_railway
# Out:
#           Meshcode  Railway_classification  Railway_Business_Type  \
# 0       5840378485                      11                      2
# 1       5840378486                      11                      2
# 2       5840378487                      11                      2
# 3       5840378495                      11                      2
# 4       5840378496                      11                      2
# ...            ...                     ...                    ...
# 101381  5841728323                      11                      2
# 101382  5841728324                      11                      2
# 101383  5841730000                      11                      2
# 101384  5841730001                      11                      2
# 101385  5841730010                      11                      2
#
#        Railway_route_name Railway_operating_company      distance
# 0                     東北線                   東日本旅客鉄道  16072.116358
# ...

# %%
gdf_railway_test
# Out:
#           Meshcode lu_code   lu_year   longitude   latitude  \
# 0       5840378485    0500  20161019  140.931875  38.990417
# 1       5840378486    0500  20161019  140.933125  38.990417
# 2       5840378487    0500  20161019  140.934375  38.990417
# 3       5840378495    0500  20161019  140.931875  38.991250
# 4       5840378496    0500  20161019  140.933125  38.991250
# ...            ...     ...       ...         ...        ...
# 101381  5841728323    0500  20160611  141.291875  39.318750
# 101382  5841728324    0500  20160611  141.293125  39.318750
# 101383  5841730000    0500  20160611  141.375625  39.250417
# 101384  5841730001    0500  20160611  141.376875  39.250417
# 101385  5841730010    0500  20160611  141.375625  39.251250
#
#                                                  geometry  \
# 0       POLYGON ((140.93125 38.99000, 140.93125 38.990...
# 1       POLYGON ((140.93250 38.99000, 140.93250 38.990...
# 2       POLYGON ((140.93375 38.99000, 140.93375 38.990...
# ...

# %%
gdf_railway_test.to_file('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/確認/奥州市　近い道路　確認/gdf_railway_test.shp', encoding='shift-jis')
# Out:
# <ipython-input-23-30e6a69956b3>:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_railway_test.to_file('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/確認/奥州市　近い道路　確認/gdf_railway_test.shp', encoding='shift-jis')
# WARNING:fiona._env:Normalized/laundered field name: 'Railway_classification' to 'Railway_cl'
# WARNING:fiona._env:Normalized/laundered field name: 'Railway_Business_Type' to 'Railway_Bu'
# WARNING:fiona._env:Normalized/laundered field name: 'Railway_route_name' to 'Railway_ro'
# WARNING:fiona._env:Normalized/laundered field name: 'Railway_operating_company' to 'Railway_op'

# %%
gdf_road
# Out:
#           Meshcode      mainroad_rID mainroad_lfSpanFr  mainroad_lfSpanTo  \
# 0       5840378485  50700-14400-i-19        2020-09-30                NaN
# 1       5840378486  50700-14400-i-19        2020-09-30                NaN
# 2       5840378487  50700-14400-i-19        2020-09-30                NaN
# 3       5840378495  50700-14400-i-19        2020-09-30                NaN
# 4       5840378496  50700-14400-i-19        2020-09-30                NaN
# ...            ...               ...               ...                ...
# 101381  5841728323  50700-14400-i-19        2020-09-30                NaN
# 101382  5841728324  50700-14400-i-19        2020-09-30                NaN
# 101383  5841730000  50700-14400-i-19        2020-09-30                NaN
# 101384  5841730001  50700-14400-i-19        2020-09-30                NaN
# 101385  5841730010  50700-14400-i-19        2020-09-30                NaN
#
#         mainroad_tmpFlg  mainroad_orgGILvl  mainroad_ftCode  mainroad_admCode  \
# ...
