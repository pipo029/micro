# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
100mメッシュのポリゴンデータと建物のポリゴンデータがある。
geopandasで100mメッシュのポリゴンデータの中に含まれるポリゴンデータの面積の割合を求めるコードを書いてください

# %%
gdf_building = gpd.read_file('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/src/基盤地図/kiban03.shp', encoding='shift-jis')
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# WARNING:fiona._env:One or several characters couldn't be converted correctly from SHIFT-JIS to UTF-8.  This warning will not be emitted anymore
# WARNING:fiona._env:One or several characters couldn't be converted correctly from SHIFT-JIS to UTF-8.  This warning will not be emitted anymore
# WARNING:fiona._env:One or several characters couldn't be converted correctly from SHIFT-JIS to UTF-8.  This warning will not be emitted anymore
# WARNING:fiona._env:One or several characters couldn't be converted correctly from SHIFT-JIS to UTF-8.  This warning will not be emitted anymore
# WARNING:fiona._env:One or several characters couldn't be converted correctly from SHIFT-JIS to UTF-8.  This warning will not be emitted anymore
# WARNING:fiona._env:One or several characters couldn't be converted correctly from SHIFT-JIS to UTF-8.  This warning will not be emitted anymore
# ...
