# %%
import geopandas as gpd
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.set_option('display.max_columns', None)

# %%
gdf_osyu_100m_mesh = gpd.read_file('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/src/国土数値情報/土地利用メッシュ/gdf_osyu_100m_mesh.shp').filter(['Meshcode','geometry'])

# %%
#環境省自動車騒音データのダウンロード
car_noise = gpd.read_file('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/src/環境省自動車騒音データ/20230526215229/point.csv', encoding='shift-jis')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-16-b13ecc81b8d1> in <cell line: 2>()
#       1 #環境省自動車騒音データのダウンロード
# ----> 2 car_noise = gpd.read_file('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/src/環境省自動車騒音データ/20230526215229/point.csv', encoding='utf-8')
#
# /usr/local/lib/python3.10/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     279             path_or_bytes = filename
#     280
# --> 281         return _read_file_fiona(
#     282             path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     283         )
#
# /usr/local/lib/python3.10/dist-packages/geopandas/io/file.py in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     368                 f_filt = features
#     369             # get list of columns
# --> 370             columns = list(features.schema["properties"])
#     371             datetime_fields = [
#     372                 k for (k, v) in features.schema["properties"].items() if v == "datetime"
#
# /usr/local/lib/python3.10/dist-packages/fiona/collection.py in schema(self)
#     291         """
#     292         if not self._schema and self.mode in ("a", "r") and self.session:
# --> 293             self._schema = self.session.get_schema()
#     294         return self._schema
#     295
#
# fiona/ogrext.pyx in fiona.ogrext.Session.get_schema()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x95 in position 0: invalid start byte

# %%
car_noise[car_noise['調査自治体名称'] == '奥州市']
# Out:
#       報告年度 調査自治体名称  一連番号 騒音測定地点番号          測定地点の住所     [1]路線名 [1]車線数 [1]道路種別  \
# 4305  2012     奥州市  1759        1       奥州市前沢区新城37     一般国道4号      2       3
# 4306  2013     奥州市  1913        1         奥州市前沢区古城     一般国道4号      2       3
# 4307  2014     奥州市   264        1        奥州市水沢区字西田     東北自動車道      4       1
# 4308  2015     奥州市   261        1        奥州市水沢区佐倉河     東北自動車道      4       1
# 4309  2016     奥州市   259        1       奥州市江刺区川原町2      水沢米里線      2       4
# 4310  2019     奥州市   256        1            奥州市水沢     東北自動車道      4       1
# 4311  2016     奥州市   260       12           奥州市前沢区     新城馬口沢線      2       4
# 4312  2016     奥州市   261       13         奥州市江刺区稲瀬     広瀬三ヶ尻線      2       4
# 4313  2016     奥州市   262       14           奥州市水沢区      北上水沢線      4       4
# 4316  2015     奥州市   264       19        奥州市水沢区高屋敷      衣川水沢線      4       4
# 4317  2012     奥州市  1760        2  奥州市江刺区八日町1-1-31   一般国道456号      2       3
# 4317   141.1756594794629     None
# 4318   141.1414829345781     None
# 4319   141.1258920285434     None
# 4320  141.13468598333333     None
# 4321  141.17557573994043     None
# 4323  141.16254314827816     None
# 4324   141.1759384684073     None
# 4325  141.12591174780636     None
# 4327  141.13730973433044     None
# 4329  141.16167053370845     None
# 4334  141.19641594089566     None
# 4335  141.16304206604653     None
# 4336   141.2579655995329     None
# 4337  141.15159538397123     None
# 4338   141.1356382751731     None
# 4339   141.2635679042715     None
# 4340  141.10958048235128     None
# 4341  141.13592296731758     None
# 4342  141.26514778301285     None
# 4343  141.10775672440374     None
# 4344  141.13734901692854     None
# 4345  141.16145499722222     None

# %%
#カラムを変更する

#現在のカラムを変数に定義
car_noise_columns = car_noise.columns
#新しく設定するカラムを変数に定義
columns_name = ['Report Year',
                'surveyed_municipality',
                'serial_number',
                'Noise_measurement point',
                'Address_of_numbering_point',
                '[1]route_name',
                '[1]number_of_lanes',
                '[1]road_classification',
                '[2]route_name',
                '[2]number_of_lanes',
                '[2]road_classification',
                'Date_of_start_of_measurement',
                'Date_of_measurement_completion',
                'Roadway_edge_distance(m)',
                'Road_site_boundary_distance(m)',
                'Height_above_ground(m)',
                'environmental_standard type',
                'noise_rank_Daytime(dB)',
                'noise_rank_nighttime(dB)',
                'noise_latitude',
                'noise_longitude']
#二つのリストをzip関数でまとめforで一つづつ辞書に入れていく
car_noise = car_noise.rename(columns = {k: v for k, v in zip(car_noise.columns, columns_name)})

# %%
#座標系を設定
if car_noise.crs is None:
    # 座標系をEPSG:4326に設定
    car_noise.set_crs(epsg=4326, inplace=True)

#自動車騒音データを奥州市に絞る
car_noise = car_noise[car_noise['Address_of_numbering_point'].str.contains('奥州市', na=False)] #na引数をna=Falseにすることで欠損値を無視することができる

#geometryカラムにpointを付与
car_noise['geometry'] = car_noise.apply(lambda x: Point(x['noise_longitude'], x['noise_latitude']), axis=1) #緯度経度座標の順番が違うと結合することが出来ない。
# Out:
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
#ポリゴンデータにポイントデータがあれば空間結合
car_noise = gpd.sjoin(gdf_osyu_100m_mesh, car_noise, op='contains', how='left')
#2つのデータフレームで同じカラム（geometry)がないと結合することが出来ない

#indexが重複しているものを削除する
car_noise = car_noise[~car_noise.index.duplicated(keep='first')]
#car_noise_osyuには6行重複があった。

#indexが重複しているものがないか確認
print(car_noise[car_noise.index.duplicated(keep=False)])#duplicated(keep=False)とすることで重複しているindexをTrueとしてその行を抜き出す

#結合した際にfiltered_gdf_road_osyuのindexを削除　結合したときのindexを残したまま別のデータフレームは結合できない
car_noise = car_noise.drop(columns=['geometry', 'index_right'], axis=1)

# %%
car_noise.to_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/奥州市　騒音/奥州市_騒音.csv')
