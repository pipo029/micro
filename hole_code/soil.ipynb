# %%
import geopandas as gpd
import pandas as pd
from copy import deepcopy
from geopandas import GeoDataFrame
from shapely.ops import unary_union

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gdf_center = gpd.read_file('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/奥州市/奥州市　重心/gdf_center.shp')

# %%
gdf_soil = gpd.read_file('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/src/土壌図データ（ベクトルデータ）/全国版_土壌/全国版/ベクトル/shp/Vec03岩手W.shp', encoding='shift-jis')

# %%
gdf_soil.columns
# Out:
# Index(['結合KEY', '土壌図番号', '土壌区連番', '地目コード', '土壌区記号', '土壌区名', '土壌統名', '県最終名',
#        '統略号', '区コード', '全国土壌統', '土壌統', '記号', '土壌群名', '土壌統群名', '作成年度', '第II等級',
#        '第III等級', '第IV等級', '面積', '色_表_名1', '色_表_名2', '色_表_名3', '色_表_記1',
#        '色_表_記2', '色_表_記3', '色_次_名1', '色_次_名2', '色_次_名3', '色_次_記1', '色_次_記2',
#        '色_次_記3', '腐植層序', '礫_有無', '礫_位置', '酸_上_有無', '酸_上_含量', '酸_上_位置',
#        '酸_上_斑1', '酸_上_斑2', '酸_上_斑3', '酸_上_斑4', '酸_上_斑5', '酸_上_斑6', '酸_上_斑7',
#        '酸_上_斑8', '酸_上_斑9', '酸_上_斑0', '酸_上_結1', '酸_上_結2', '酸_上_結3', '酸_上_結4',
#        '酸_上_結5', '酸_下_有無', '酸_下_含量', '酸_下_位置', '酸_下_斑1', '酸_下_斑2', '酸_下_斑3',
#        '酸_下_斑4', '酸_下_斑5', '酸_下_斑6', '酸_下_斑7', '酸_下_斑8', '酸_下_斑9', '酸_下_斑0',
#        '酸_下_結1', '酸_下_結2', '酸_下_結3', '酸_下_結4', '酸_下_結5', '土性_表土', '土性次表土',
#        '泥炭', '黒泥', 'グライ層', '母材_上', '堆積_上', '母材_中', '堆積_中', '母材_下', '堆積_下',
#        '施肥改善型', '県NO_', 'S_TKY2JGD', 'geometry'],
#       dtype='object')
