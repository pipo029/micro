# %%
import pandas as pd
import geopandas as gpd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gdf_hole = pd.read_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/src/マンホール/yokohama_2018_2022.csv', encoding='cp932')
# Out:
# <ipython-input-3-fef40a7a6534>:1: DtypeWarning: Columns (94,98,101,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   gdf_hole = pd.read_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/src/マンホール/yokohama_2018_2022.csv', encoding='cp932')

# %%
gdf_mainroad = pd.read_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/横浜市/横浜市　最近傍道路/横浜市_主要道路.csv')

# %%
gdf_highway = pd.read_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/横浜市/横浜市　最近傍高速道路/横浜市_高速道路.csv')
# Out:
# <ipython-input-5-6cbdd6888091>:1: DtypeWarning: Columns (10,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   gdf_highway = pd.read_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/横浜市/横浜市　最近傍高速道路/横浜市_高速道路.csv')

# %%
gdf_station = pd.read_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/横浜市/横浜市　最近傍鉄道/横浜市_駅.csv')

# %%
gdf_factory = pd.read_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/横浜市/横浜市　最近傍工場/横浜市_主要工場.csv')
# Out:
# <ipython-input-7-f9a2218920de>:1: DtypeWarning: Columns (6,8,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   gdf_factory = pd.read_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/横浜市/横浜市　最近傍工場/横浜市_主要工場.csv')

# %%
#空間結合した後にgeomeryを加えられるように連番を追加
number = [i for i in range(len(gdf_hole))]
gdf_hole['number'] = number
gdf_mainroad['number'] = number
gdf_highway['number'] = number
gdf_station['number'] = number
gdf_factory['number'] = number

# %%
#gdf_holeにデータフレームを結合
gdf_merge = pd.merge(gdf_hole, gdf_mainroad, on='number')

# %%
#gdf_holeにデータフレームを結合
gdf_merge = pd.merge(gdf_merge, gdf_highway, on='number')

# %%
#gdf_holeにデータフレームを結合
gdf_merge = pd.merge(gdf_merge, gdf_station, on='number')
# Out:
# <ipython-input-11-bd80ed5a0d62>:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'人孔番号_x'} in the result is deprecated and will raise a MergeError in a future version.
#   gdf_merge = pd.merge(gdf_merge, gdf_station, on='number')

# %%
#gdf_holeにデータフレームを結合
gdf_merge = pd.merge(gdf_merge, gdf_factory, on='number')

# %%
#numberはいらないので削除
gdf_merge.drop('number', axis=1, inplace=True)

# %%
gdf_merge.to_csv('/content/drive/MyDrive/水道管劣化予測/水道管劣化予測/result/横浜市/データ結合/manhole_near_ver4.csv', index=False)
